# %% [markdown]
# # Use Llama.3.2-Vision via Ollama with Langchain

# %%
# !ollama list
#!ollama rm llama3.2-vision
#!ollama pull mxbai-embed-large
#!ollama run llama3.2-vision
# !ollama --version
# Out:
# NAME                       ID              SIZE      MODIFIED
# llama3.2-vision:latest     085a1fdae525    7.9 GB    13 hours ago
# llama3:latest              365c0bd3c000    4.7 GB    5 weeks ago
# nomic-embed-text:latest    0a109f422b47    274 MB    8 months ago
# ollama version is 0.4.7

# %%
filename = "Dinh et al 2017.pdf"

file_path = f"paper/{filename}"

# %%
#import streamlit as st
from PIL import Image
import io

# %%
image = Image.open("paper/page_1.png")
#image

# %%
# !ollama run llama3.2-vision "describe this image: /Users/mn9lu5b/Library/CloudStorage/OneDrive-Allianz/Github_priv/rag_sandbox/paper/page_1.png"
# Out:
# Added image '/Users/mn9lu5b/Library/CloudStorage/OneDrive-Allianz/Github_priv/rag_sandbox/paper/page_1.png'
# ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ This infographic presents the first page of a research paper titled "Densit
# "Density Estimation Using Real NVP." The authors, Laurent Dinh and Jascha S
# Sohl-Dickstein from Google Brain (Canada), are credited with publishing the
# the paper in 2017 as part of the International Conference on Learning Repre
# Representations (ICLR).
#
# The title is prominently displayed at the top of the page, followed by the
# abstract. The abstract provides a concise overview of the research focus an
# and methodology employed to achieve its objectives.
#
# Below the abstract, an introduction section delves into the significance of
# of density estimation in machine learning. This section outlines the challe
# challenges associated with traditional approaches to this task, emphasizing
# emphasizing the limitations of existing methods and their inability to effi
# efficiently model complex distributions.
#
# The page concludes with a list of references cited throughout the paper, se
# serving as a valuable resource for further exploration and understanding of
# of the research presented.

# %%
import fitz
from PIL import Image

# Load PDF
doc = fitz.open(file_path)

# %%
# Convert each page to an image in jpg format
for page_number in range(len(doc)):
    page = doc.load_page(page_number)
    pix = page.get_pixmap()
    img = Image.frombytes("RGB", [pix.width, pix.height], pix.samples)

    # Save the image
    img.save(f"paper/page_{page_number + 1}.jpg")

print("PDF pages converted to images successfully!")
# Out:
# PDF pages converted to images successfully!

# %%
import ollama

# Define the image path
image_path = '/Users/mn9lu5b/Library/CloudStorage/OneDrive-Allianz/Github_priv/rag_sandbox/paper/page_1.jpg'

# Query the model
try:
    response = ollama.chat(
        model='llama3.2-vision',  # Use the full model name
        messages=[
            {
                'role': 'user',
                'content': 'What is in this image?',
                'images': [image_path]
            }
        ]
    )
    # print(response)
except Exception as e:
    print(f"An error occurred: {e}")

# %%
# Extract the model's response about the image
cleaned_text = response.message.content.strip()

print(f"Model Response: {cleaned_text}")
# Out:
# Model Response: The image displays the first page of a conference paper titled "Density Estimation Using Real NVP." The authors are Laurent Dinh, Jascha Sohl-Dickstein, and Samp Bengio. They all work at Google Brain.
#
# The paper was published as part of ICLR 2017 (International Conference on Learning Representations) in February 2017. This date is shown in the top-left corner in small text.
#
# This image shows the abstract, introduction, and related work sections of the paper. The abstract states that unsupervised learning can be used to solve machine learning challenges like sampling, inference, and evaluation. It also discusses how generative models have limitations when modeling real-world data.
#
# The introduction explains how the domain of representation learning has undergone significant advances due to improved supervised techniques. However, unsupervised learning is a critical area that requires more research because it can be used for large-scale datasets.
#
# Finally, the section on related work focuses on probabilistic generative models and their limitations when modeling real-world data. It also discusses recent advancements in this field.

# %%
from langchain_community.chat_models import ChatOllama
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate

llm = ChatOllama(model="llama3.2-vision", temperature=0.1)

# %%
import base64
from io import BytesIO
import pprint
from IPython.display import HTML, display
from PIL import Image

def convert_to_base64(pil_image):
    """
    Convert PIL images to Base64 encoded strings

    :param pil_image: PIL image
    :return: Re-sized Base64 string
    """

    buffered = BytesIO()
    pil_image.save(buffered, format="JPEG")  # You can change the format if needed
    img_str = base64.b64encode(buffered.getvalue()).decode("utf-8")
    return img_str

def plt_img_base64(img_base64):
    """
    Disply base64 encoded string as image

    :param img_base64:  Base64 string
    """
    # Create an HTML img tag with the base64 string as the source
    image_html = f'<img src="data:image/jpeg;base64,{img_base64}" />'
    # Display the image by rendering the HTML
    display(HTML(image_html))

page_nr = 3
file_path = f'/Users/mn9lu5b/Library/CloudStorage/OneDrive-Allianz/Github_priv/rag_sandbox/paper/page_{page_nr}.jpg'
pil_image = Image.open(file_path)

# Convert the image to base64
image_b64 = convert_to_base64(pil_image)

# Display the image
plt_img_base64(image_b64)
# Out:
# <img src="data:image/jpeg;base64,..." />

# %%
from langchain_core.messages import HumanMessage

llm = ChatOllama(model="llama3.2-vision", temperature=0)

def prompt_func(data):
    text = data["text"]
    image = data["image"]

    image_part = {
        "type": "image_url",
        "image_url": f"data:image/jpeg;base64,{image}",
    }

    content_parts = []

    text_part = {"type": "text", "text": text}

    content_parts.append(image_part)
    content_parts.append(text_part)

    return [HumanMessage(content=content_parts)]


chain = prompt_func | llm | StrOutputParser()

question = "Give an example about the topic of section 3.1"

text = f"""
    You will be provided with an image of a document. 
    Your task is to answer the user question. 
    If you are unable to answer the question, please do not come up with a random answer.     
Question: {question}
"""

query_chain = chain.invoke(
    {
    "text": text, 
    "image": image_b64
    }
)

pprint.pprint(query_chain)
# Out:
# ('The topic of Section 3.1 in the provided research paper is "Change of '
#  'variable formula". This section discusses how to transform variables in '
#  'probability distributions using the change of variable formula.\n'
#  '\n'
#  '**Example:**\n'
#  '\n'
#  'Suppose we have a random variable X that follows a normal distribution with '
#  'mean μ and variance σ^2, denoted as N(μ, σ^2). We want to find the '
#  'probability density function (PDF) of Y = 2X + 3.\n'
#  '\n'
#  'To do this, we can use the change of variable formula:\n'
#  '\n'
#  'f_Y(y) = f_X(x) \\* |dx/dy|\n'
#  '\n'
#  'where f_X(x) is the PDF of X and dx/dy is the Jacobian of the '
#  'transformation.\n'
#  '\n'
#  'In this case, the transformation is y = 2x + 3, so we have:\n'
#  '\n'
#  'dy/dx = 2\n'
#  '\n'
#  'The Jacobian is therefore:\n'
#  '\n'
#  '|dx/dy| = 1/2\n'
#  '\n'
#  'Now, we can plug in the values into the change of variable formula:\n'
#  '\n'
#  'f_Y(y) = f_X(x) \\* |dx/dy|\n'
#  '= f_X((y-3)/2) \\* (1/2)\n'
#  '= (1/√(2πσ^2)) \\* exp(-((y-3)/2 - μ)^2 / 2σ^2) \\* (1/2)\n'
#  '\n'
#  'Simplifying the expression, we get:\n'
#  '\n'
#  'f_Y(y) = (1/√(4πσ^2)) \\* exp(-(y-3-2μ)^2 / 4σ^2)\n'
#  '\n'
#  'This is the PDF of Y.\n'
#  '\n'
#  '**Answer:**\n'
#  '\n'
#  'The example illustrates how to use the change of variable formula to '
#  'transform a random variable X into another random variable Y. By applying '
#  'the formula, we can find the probability density function of Y in terms of '
#  'the original distribution of X.')
